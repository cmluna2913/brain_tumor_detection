# %%
# for data path
import configparser

# basics
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# image importing
import os
import cv2

# %%
# importing config.ini to get data path
config = configparser.ConfigParser()
config.read("src/config.ini") 

path = config['paths']['data']
print(path)
# Out:
# C://Users/Cristian/Documents/Coding_Scripts/Data/bt_detection/

# %%
# folder of no brain tumor images
no_bt = path+"no/"
# folder of yes brain tumor images
yes_bt = path+"yes/"

#def import_images(path):
# iterate through images in folder
for img in os.listdir(no_bt):
    # create image path
    img_path = no_bt+img
    # import and make grayscale
    img_arr = cv2.imread(img_path)
    img_arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2GRAY)

    # get edges of brain in images
    edge = cv2.Canny(img_arr, 50,150)
    contours, hierarchy = cv2.findContours(edge, 
    cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    
    # get dimension for cropping image to just the brain
    x,y,w,h = cv2.boundingRect(edge)
    plt.imshow(cv2.rectangle(img_arr, (x-1,y-1), (x+w+1, y+h+1), (255,0,0),3))
    plt.show()

    # crop image
    cropped = img_arr[y:y+h, x:x+w]
    plt.imshow(cropped)
    plt.show()

    # only want to test on first one
    break
# Out:
# (92, 48, 447, 530)
# <class 'int'>
# (9, 3, 156, 193)
# <class 'int'>
# (87, 16, 124, 146)
# <class 'int'>
# (66, 6, 145, 172)
# <class 'int'>
# (79, 0, 148, 167)
# <class 'int'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Cristian\Documents\Coding_Scripts\brain_tumor_detection\main.ipynb Cell 3' in <cell line: 6>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Documents/Coding_Scripts/brain_tumor_detection/main.ipynb#ch0000006?line=15'>16</a> print(type(x))
#      <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Documents/Coding_Scripts/brain_tumor_detection/main.ipynb#ch0000006?line=16'>17</a> plt.imshow(cv2.rectangle(img_arr, (x-1,y-1), (x+w+1, y+h+1), (255,0,0),3))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Documents/Coding_Scripts/brain_tumor_detection/main.ipynb#ch0000006?line=17'>18</a> plt.show()
#      <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Documents/Coding_Scripts/brain_tumor_detection/main.ipynb#ch0000006?line=18'>19</a> cropped = img_arr[y:y+h, x:x+w]
#      <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Documents/Coding_Scripts/brain_tumor_detection/main.ipynb#ch0000006?line=19'>20</a> plt.imshow(cropped)
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# --> 368 return _backend_mod.show(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib_inline\backend_inline.py:43, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
#      41         display(
#      42             figure_manager.canvas.figure,
# ---> 43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib_inline\backend_inline.py:231, in _fetch_figure_metadata(fig)
#     228 # determine if a background is needed for legibility
#     229 if _is_transparent(fig.get_facecolor()):
#     230     # the background is transparent
# --> 231     ticksLight = _is_light([label.get_color()
#     232                             for axes in fig.axes
#     233                             for axis in (axes.xaxis, axes.yaxis)
#     234                             for label in axis.get_ticklabels()])
#     235     if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236         # there are one or more tick labels, all with the same lightness
#     237         return {'needs_background': 'dark' if ticksLight[0] else 'light'}
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib_inline\backend_inline.py:234, in <listcomp>(.0)
#     228 # determine if a background is needed for legibility
#     229 if _is_transparent(fig.get_facecolor()):
#     230     # the background is transparent
#     231     ticksLight = _is_light([label.get_color()
#     232                             for axes in fig.axes
#     233                             for axis in (axes.xaxis, axes.yaxis)
# --> 234                             for label in axis.get_ticklabels()])
#     235     if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236         # there are one or more tick labels, all with the same lightness
#     237         return {'needs_background': 'dark' if ticksLight[0] else 'light'}
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\axis.py:1249, in Axis.get_ticklabels(self, minor, which)
#    1247 if minor:
#    1248     return self.get_minorticklabels()
# -> 1249 return self.get_majorticklabels()
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\axis.py:1201, in Axis.get_majorticklabels(self)
#    1199 def get_majorticklabels(self):
#    1200     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1201     ticks = self.get_major_ticks()
#    1202     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1203     labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\axis.py:1371, in Axis.get_major_ticks(self, numticks)
#    1369 r"""Return the list of major `.Tick`\s."""
#    1370 if numticks is None:
# -> 1371     numticks = len(self.get_majorticklocs())
#    1373 while len(self.majorTicks) < numticks:
#    1374     # Update the new tick label properties from the old.
#    1375     tick = self._get_tick(major=True)
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\axis.py:1277, in Axis.get_majorticklocs(self)
#    1275 def get_majorticklocs(self):
#    1276     """Return this Axis' major tick locations in data coordinates."""
# -> 1277     return self.major.locator()
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\ticker.py:2114, in MaxNLocator.__call__(self)
#    2112 def __call__(self):
#    2113     vmin, vmax = self.axis.get_view_interval()
# -> 2114     return self.tick_values(vmin, vmax)
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\ticker.py:2122, in MaxNLocator.tick_values(self, vmin, vmax)
#    2119     vmin = -vmax
#    2120 vmin, vmax = mtransforms.nonsingular(
#    2121     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2122 locs = self._raw_ticks(vmin, vmax)
#    2124 prune = self._prune
#    2125 if prune == 'lower':
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\ticker.py:2061, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2059 if self._nbins == 'auto':
#    2060     if self.axis is not None:
# -> 2061         nbins = np.clip(self.axis.get_tick_space(),
#    2062                         max(1, self._min_n_ticks - 1), 9)
#    2063     else:
#    2064         nbins = 9
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\axis.py:2525, in YAxis.get_tick_space(self)
#    2523 def get_tick_space(self):
#    2524     ends = mtransforms.Bbox.from_bounds(0, 0, 1, 1)
# -> 2525     ends = ends.transformed(self.axes.transAxes -
#    2526                             self.figure.dpi_scale_trans)
#    2527     length = ends.height * 72
#    2528     # Having a spacing of at least 2 just looks good.
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\transforms.py:492, in BboxBase.transformed(self, transform)
#     488 """
#     489 Construct a `Bbox` by statically transforming this one by *transform*.
#     490 """
#     491 pts = self.get_points()
# --> 492 ll, ul, lr = transform.transform(np.array(
#     493     [pts[0], [pts[0, 0], pts[1, 1]], [pts[1, 0], pts[0, 1]]]))
#     494 return Bbox([ll, [lr[0], ul[1]]])
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\transforms.py:1503, in Transform.transform(self, values)
#    1500 values = values.reshape((-1, self.input_dims))
#    1502 # Transform the values
# -> 1503 res = self.transform_affine(self.transform_non_affine(values))
#    1505 # Convert the result back to the shape of the input values.
#    1506 if ndim == 0:
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\transforms.py:2419, in CompositeGenericTransform.transform_affine(self, points)
#    2417 def transform_affine(self, points):
#    2418     # docstring inherited
# -> 2419     return self.get_affine().transform(points)
#
# File c:\Users\Cristian\anaconda3\envs\updated\lib\site-packages\matplotlib\transforms.py:2446, in CompositeGenericTransform.get_affine(self)
#    2444     return self._b.get_affine()
#    2445 else:
# -> 2446     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2447                            self._a.get_affine().get_matrix()))
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
ano_bt = path+"no/"
yes_bt = path+"yes/"


#def import_images(path):
for img in os.listdir(no_bt):
    break
    img_path = no_bt+img
    img_arr = Image.open(img_path)
    #img_arr = img_arr.filter(ImageFilter.CONTOUR)
    #img_arr = ImageOps.grayscale(img_arr)
    # size = min(np.array(img_arr).shape)
    # print(size)
    # print(np.array(img_arr).shape)
    # img_arr = img_arr.crop((0,0,size,size))
    # print(np.array(img_arr).shape)
    plt.imshow(img_arr)
    plt.show()
